# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('Indian automoble buying behavour study 1.0.csv')
import warnings
warnings.filterwarnings('ignore')

# %%
df.head()
# Out:
#    Age Profession Marrital Status      Education  No of Dependents  \
# 0   27   Salaried          Single  Post Graduate                 0
# 1   35   Salaried         Married  Post Graduate                 2
# 2   45   Business         Married       Graduate                 4
# 3   41   Business         Married  Post Graduate                 3
# 4   31   Salaried         Married  Post Graduate                 2
#
#   Personal loan House Loan Wife Working   Salary  Wife Salary  Total Salary  \
# 0           Yes         No           No   800000            0        800000
# 1           Yes        Yes          Yes  1400000       600000       2000000
# 2           Yes        Yes           No  1800000            0       1800000
# 3            No         No          Yes  1600000       600000       2200000
# 4           Yes         No          Yes  1800000       800000       2600000
#
#      Make    Price
# 0     i20   800000
# 1    Ciaz  1000000
# 2  Duster  1200000
# 3    City  1200000
# ...

# %%
def age_group(age):
    if 1 <= age <= 18:
        return "Teenagers"
    elif 19 <= age <= 40:
        return "Adults"
    elif age > 40:
        return "Old persons"
    else:
        return "Unknown"

# %%
df['Age Group'] = df['Age'].apply(age_group)
df.head()
# Out:
#    Age Profession Marrital Status      Education  No of Dependents  \
# 0   27   Salaried          Single  Post Graduate                 0
# 1   35   Salaried         Married  Post Graduate                 2
# 2   45   Business         Married       Graduate                 4
# 3   41   Business         Married  Post Graduate                 3
# 4   31   Salaried         Married  Post Graduate                 2
#
#   Personal loan House Loan Wife Working   Salary  Wife Salary  Total Salary  \
# 0           Yes         No           No   800000            0        800000
# 1           Yes        Yes          Yes  1400000       600000       2000000
# 2           Yes        Yes           No  1800000            0       1800000
# 3            No         No          Yes  1600000       600000       2200000
# 4           Yes         No          Yes  1800000       800000       2600000
#
#      Make    Price    Age Group
# 0     i20   800000       Adults
# 1    Ciaz  1000000       Adults
# ...

# %%
df=df.drop(['Age'],axis=1)
df.head()
# Out:
#   Profession Marrital Status      Education  No of Dependents Personal loan  \
# 0   Salaried          Single  Post Graduate                 0           Yes
# 1   Salaried         Married  Post Graduate                 2           Yes
# 2   Business         Married       Graduate                 4           Yes
# 3   Business         Married  Post Graduate                 3            No
# 4   Salaried         Married  Post Graduate                 2           Yes
#
#   House Loan Wife Working   Salary  Wife Salary  Total Salary    Make  \
# 0         No           No   800000            0        800000     i20
# 1        Yes          Yes  1400000       600000       2000000    Ciaz
# 2        Yes           No  1800000            0       1800000  Duster
# 3         No          Yes  1600000       600000       2200000    City
# 4         No          Yes  1800000       800000       2600000     SUV
#
#      Price    Age Group
# 0   800000       Adults
# 1  1000000       Adults
# ...

# %%
df['Personal loan'] = df['Personal loan'].astype(str).str.lower().map({'yes': 1, 'no': 0})

# %%
df['House Loan']= df['House Loan'].astype(str).str.lower().map({'yes':1,'no':0})

# %%
df['Wife Working']= df['Wife Working'].astype(str).str.lower().map({'yes':1,'no':0})

# %%
df.head()
# Out:
#   Profession Marrital Status      Education  No of Dependents  Personal loan  \
# 0   Salaried          Single  Post Graduate                 0              1
# 1   Salaried         Married  Post Graduate                 2              1
# 2   Business         Married       Graduate                 4              1
# 3   Business         Married  Post Graduate                 3              0
# 4   Salaried         Married  Post Graduate                 2              1
#
#    House Loan  Wife Working   Salary  Wife Salary  Total Salary    Make  \
# 0           0           0.0   800000            0        800000     i20
# 1           1           1.0  1400000       600000       2000000    Ciaz
# 2           1           0.0  1800000            0       1800000  Duster
# 3           0           1.0  1600000       600000       2200000    City
# 4           0           1.0  1800000       800000       2600000     SUV
#
#      Price    Age Group
# 0   800000       Adults
# ...

# %%
df.shape
# Out:
# (99, 13)

# %%
pd.isnull(df).sum()
# Out:
# Profession          0
# Marrital Status     0
# Education           0
# No of Dependents    0
# Personal loan       0
# House Loan          0
# Wife Working        1
# Salary              0
# Wife Salary         0
# Total Salary        0
# Make                0
# Price               0
# Age Group           0
# dtype: int64

# %%
df.fillna(0,inplace=True)

# %%
df.head()
# Out:
#   Profession Marrital Status      Education  No of Dependents  Personal loan  \
# 0   Salaried          Single  Post Graduate                 0              1
# 1   Salaried         Married  Post Graduate                 2              1
# 2   Business         Married       Graduate                 4              1
# 3   Business         Married  Post Graduate                 3              0
# 4   Salaried         Married  Post Graduate                 2              1
#
#    House Loan  Wife Working   Salary  Wife Salary  Total Salary    Make  \
# 0           0           0.0   800000            0        800000     i20
# 1           1           1.0  1400000       600000       2000000    Ciaz
# 2           1           0.0  1800000            0       1800000  Duster
# 3           0           1.0  1600000       600000       2200000    City
# 4           0           1.0  1800000       800000       2600000     SUV
#
#      Price    Age Group
# 0   800000       Adults
# ...

# %%
pd.isnull(df).sum()
# Out:
# Profession          0
# Marrital Status     0
# Education           0
# No of Dependents    0
# Personal loan       0
# House Loan          0
# Wife Working        0
# Salary              0
# Wife Salary         0
# Total Salary        0
# Make                0
# Price               0
# Age Group           0
# dtype: int64

# %%
df.describe()
# Out:
#        No of Dependents  Personal loan  House Loan  Wife Working  \
# count         99.000000      99.000000   99.000000     99.000000
# mean           2.181818       0.323232    0.373737      0.525253
# std            1.335265       0.470091    0.486257      0.501903
# min            0.000000       0.000000    0.000000      0.000000
# 25%            2.000000       0.000000    0.000000      0.000000
# 50%            2.000000       0.000000    0.000000      1.000000
# 75%            3.000000       1.000000    1.000000      1.000000
# max            4.000000       1.000000    1.000000      1.000000
#
#              Salary   Wife Salary  Total Salary         Price
# count  9.900000e+01  9.900000e+01  9.900000e+01  9.900000e+01
# mean   1.736364e+06  5.343434e+05  2.270707e+06  1.194040e+06
# std    6.736217e+05  6.054450e+05  1.050777e+06  4.376955e+05
# min    2.000000e+05  0.000000e+00  2.000000e+05  1.100000e+05
# 25%    1.300000e+06  0.000000e+00  1.550000e+06  8.000000e+05
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Profession        99 non-null     object
#  1   Marrital Status   99 non-null     object
#  2   Education         99 non-null     object
#  3   No of Dependents  99 non-null     int64
#  4   Personal loan     99 non-null     int64
#  5   House Loan        99 non-null     int64
#  6   Wife Working      99 non-null     float64
#  7   Salary            99 non-null     int64
#  8   Wife Salary       99 non-null     int64
#  9   Total Salary      99 non-null     int64
#  10  Make              99 non-null     object
#  11  Price             99 non-null     int64
#  12  Age Group         99 non-null     object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 10.2+ KB

# %%
df.columns
# Out:
# Index(['Profession', 'Marrital Status', 'Education', 'No of Dependents',
#        'Personal loan', 'House Loan', 'Wife Working', 'Salary', 'Wife Salary',
#        'Total Salary', 'Make', 'Price', 'Age Group'],
#       dtype='object')

# %% [markdown]
# Exploratory data analysis

# %%
plt.figure(figsize=(12,6))
df.boxplot()
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
sns_data=df.groupby(['Make'],as_index=False)['Price'].sum().sort_values(by='Price',ascending=False)
sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(x='Make',y='Price',data=sns_data,palette='viridis')
# Out:
# <Axes: xlabel='Make', ylabel='Price'>

# %% [markdown]
# Insights:- The sales of EV Cars of SUV and Creata is more compared to other cars in india.The customers are showing interest to purchase SUV and Creata more than others

# %%
sns_data = df.groupby(['Profession'], as_index=False)['Salary'].sum().sort_values(by='Salary', ascending=False)
plt.figure(figsize=(5, 5))  
plt.pie(sns_data['Salary'], labels=sns_data['Profession'], autopct='%1.1f%%', colors=plt.cm.Set1.colors, startangle=140)
plt.title("Salary Distribution by Profession")
plt.show()

# %% [markdown]
# Insights:-Here,we can get to known that the customers who are employed are earning more than business professionals

# %%
sns.scatterplot(x=df['Salary'], y=df['Price'])
plt.show()

# %% [markdown]
# Insights:- This plot tells about the Salary of the customer Versus Price of EV Cars

# %%
sns.violinplot(x='Age Group',y='Salary',data=df,palette='Set1')
# Out:
# <Axes: xlabel='Age Group', ylabel='Salary'>

# %% [markdown]
# Insights:-The salary of the customers of age above 40(old persons) is more than the salary of the adults of the age between 18 to 40

# %% [markdown]
# Segmentation- Using K nearest neighbors

# %%
x=df.drop('Age Group',axis=1)
y=df['Age Group']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=25)

# %%
print(x.dtypes)
# Out:
# Profession           object
# Marrital Status      object
# Education            object
# No of Dependents      int64
# Personal loan         int64
# House Loan            int64
# Wife Working        float64
# Salary                int64
# Wife Salary           int64
# Total Salary          int64
# Make                 object
# Price                 int64
# dtype: object

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder(drop='first', sparse_output=False) 
encoded_cols = encoder.fit_transform(x[['Profession']])  
encoded_df = pd.DataFrame(encoded_cols, columns=encoder.get_feature_names_out(['Profession']))
x = pd.concat([x.drop(columns=['Profession']), encoded_df], axis=1)

# %%
categorical_cols = x.select_dtypes(include=['object']).columns  
encoder = OneHotEncoder(drop='first', sparse_output=False)  
encoded_cols = encoder.fit_transform(x[categorical_cols])
encoded_df = pd.DataFrame(encoded_cols, columns=encoder.get_feature_names_out(categorical_cols))
x = pd.concat([x.drop(columns=categorical_cols), encoded_df], axis=1)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_scaled = sc.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier(n_neighbors=12)
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=12)

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.65

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#       Adults       0.91      0.62      0.74        16
#  Old persons       0.33      0.75      0.46         4
#
#     accuracy                           0.65        20
#    macro avg       0.62      0.69      0.60        20
# weighted avg       0.79      0.65      0.68        20

# %%
from sklearn.metrics import confusion_matrix
plt.figure(figsize=(4, 3))
sns.heatmap(confusion_matrix(y_pred,y_test),annot=True,cmap='viridis')
plt.title('Confusion_Matrix')
plt.show()

# %%
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=12)

# %%
y_train_pred=model.predict(x_train)

# %%
accuracy_score(y_train_pred,y_train)
# Out:
# 0.8481012658227848

# %%
y_pred=model.predict(x_test)

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.65

# %% [markdown]
# Segmentation - Using K Means Clustering

# %%
from sklearn.cluster import KMeans
wcss=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i,init='k-means++',random_state=42)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11),wcss)
plt.title('Elbow method')
plt.show()

# %%
kmeans=KMeans(n_clusters=5,init='k-means++',random_state=42)
y_kmeans=kmeans.fit_predict(x)

# %%
from sklearn.metrics import davies_bouldin_score, silhouette_score
from sklearn.decomposition import PCA
db_scores = []
silhouette_scores = []
for k in range(2, 11):  
    kmeans = KMeans(n_clusters=k, random_state=42)
    clusters = kmeans.fit_predict(x_scaled)
    db_index = davies_bouldin_score(x_scaled, clusters)
    silhouette_avg = silhouette_score(x_scaled, clusters)
    db_scores.append(db_index)
    silhouette_scores.append(silhouette_avg)
    print(f"Number of clusters: {k}, DB Index: {db_index}, Silhouette Score: {silhouette_avg}")
# Out:
# Number of clusters: 2, DB Index: 2.0001577863602864, Silhouette Score: 0.16622055607044892
# Number of clusters: 3, DB Index: 1.7093744959350108, Silhouette Score: 0.1479583646723202
# Number of clusters: 4, DB Index: 1.9431494582908668, Silhouette Score: 0.14848467000838173
# Number of clusters: 5, DB Index: 1.93667929874955, Silhouette Score: 0.1623199357982922
# Number of clusters: 6, DB Index: 1.6738341737780704, Silhouette Score: 0.1826372427151581
# Number of clusters: 7, DB Index: 1.4920874790694305, Silhouette Score: 0.21204203092038346
# Number of clusters: 8, DB Index: 1.4614546233096228, Silhouette Score: 0.20951321561071987
# Number of clusters: 9, DB Index: 1.3711141023530748, Silhouette Score: 0.23467486324720527
# Number of clusters: 10, DB Index: 1.4052015895469896, Silhouette Score: 0.244352739498554

# %%
optimal_clusters = np.argmin(db_scores) + 2  
print(f"Optimal number of clusters: {optimal_clusters}")
# Out:
# Optimal number of clusters: 9

# %%
kmeans = KMeans(n_clusters=optimal_clusters, random_state=42)
final_clusters = kmeans.fit_predict(x_scaled)
df['Cluster'] = final_clusters

# %%
pca = PCA(n_components=2)
x_pca = pca.fit_transform(x_scaled)
df['PCA1'] = x_pca[:, 0]
df['PCA2'] = x_pca[:, 1]

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='PCA1', y='PCA2', hue='Cluster', data=df, palette='tab10', s=100)
plt.title('Clusters Visualization based on Age Group')
plt.show()
